# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
plt.style.use('seaborn-ticks')
import matplotlib.patches as patches

# %%
import os, random
import cv2

from tqdm.auto import trange

# %% [markdown]
# # Data Exploration

# %%
images_path = "../face_mask_dataset/Medical Mask/images"
annotations_path = "../face_mask_dataset/Medical Mask/annotations"
train = pd.read_csv("../face_mask_dataset/train.csv")
submission = pd.read_csv("../face_mask_dataset/submission.csv")

# %%
print(len(train))
train.head()
# Out:
# 15412
#        name   x1   x2   y1   y2       classname
# 0  2756.png   69  126  294  392  face_with_mask
# 1  2756.png  505   10  723  283  face_with_mask
# 2  2756.png   75  252  264  390   mask_colorful
# 3  2756.png  521  136  711  277   mask_colorful
# 4  6098.jpg  360   85  728  653    face_no_mask

# %%
fig, ax = plt.subplots(figsize=(20, 6))

train['classname'].value_counts().plot.bar()
ax.grid()
x_offset = -0.03
y_offset = 0.05
for p in ax.patches:
    b = p.get_bbox()
    val = "{:.2f}".format(b.y1 + b.y0)        
    ax.annotate(val, ((b.x0 + b.x1)/2 + x_offset, b.y1 + y_offset))

# %%
len(os.listdir(images_path))
# Out:
# 6024

# %%
images = os.listdir(images_path)
annotations = os.listdir(annotations_path)
images.sort()
annotations.sort()
print(len(annotations),len(images))
# Out:
# 4326 6024

# %%
train_images = images[1698:]
test_images = images[:1698]

# %%
img_tr = random.choices(train_images, k=5)
img_ts = random.choices(test_images, k=5)

fig, ax = plt.subplots(nrows=2, ncols=5, figsize=(20, 6))
for i in range(5):
    ax[0][i].imshow(plt.imread(os.path.join(images_path,img_tr[i])))
    ax[1][i].imshow(plt.imread(os.path.join(images_path,img_ts[i])))

# %%
train= train[train['classname'].isin(['face_with_mask','face_no_mask'])]
train.sort_values('name',axis=0,inplace=True)

# %%
bbox=[]
for i in range(len(train)):
    arr=[]
    for j in train.iloc[i][["x1",'x2','y1','y2']]:
        arr.append(j)
    bbox.append(arr)
train["bbox"]=bbox 

def get_boxes(id):
    boxes=[]
    for i in train[train["name"]==str(id)]["bbox"]:
        boxes.append(i)
    return boxes

# %%
fig, ax = plt.subplots(nrows=1, ncols=5, figsize=(20, 6))
for i in range(5):
    ax[i].imshow(plt.imread(os.path.join(images_path,img_tr[i])))
    boxes = get_boxes(img_tr[i])
    for box in boxes:
        rect = patches.Rectangle((box[0],box[1]),box[2]-box[0],box[3]-box[1],linewidth=2,edgecolor='r',facecolor='none')
        ax[i].add_patch(rect)

# %% [markdown]
# # Preparing Data

# %%
from keras.utils import normalize, to_categorical

img_size = (96, 96, 1)
# Out:
# Using TensorFlow backend.

# %%
X = []
y = []

for i in trange(len(train)):
    row = train.iloc[i].values
    img = cv2.imread(os.path.join(images_path,row[0]), cv2.IMREAD_GRAYSCALE)
    img = img[row[2]:row[4], row[1]:row[3]]
    img = cv2.resize(img, img_size[:2])
    X.append(img)
    if row[5] == 'face_with_mask':
        y.append(0)
    elif row[5] == 'face_no_mask':
        y.append(1)
    else:
        print('error')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=5749.0), HTML(value='')))

# %%
X = np.array(X).reshape(-1, 96, 96, 1)
X = normalize(X, axis=1)

y = np.array(y)

# %% [markdown]
# # Modelling

# %%
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout, BatchNormalization
from keras.callbacks import EarlyStopping, ModelCheckpoint, ReduceLROnPlateau
from keras.utils import plot_model
from keras.optimizers import Adam

# %%
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10)
filepath = "face_mask_model.h5"
ckpt = ModelCheckpoint(filepath, monitor='loss', verbose=1, save_best_only=True, mode='min')
rlp = ReduceLROnPlateau(monitor='loss', patience=3, factor=0.2)

opt = Adam(lr=0.001, decay=0.000001)

# %%
def cnn(image_size):
    classifier = Sequential()
    classifier.add(Conv2D(32, (3, 3), input_shape=image_size, activation='relu', padding='same'))
#     classifier.add(BatchNormalization(axis=-1))
    classifier.add(MaxPooling2D(pool_size = (3, 3)))
    classifier.add(Dropout(0.25))
    
    classifier.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
    classifier.add(BatchNormalization(axis=-1))
    
    classifier.add(Conv2D(64, (3, 3), activation='relu', padding='same'))
#     classifier.add(BatchNormalization(axis=-1))
    classifier.add(MaxPooling2D(pool_size = (2, 2)))
    classifier.add(Dropout(0.25))
    
    classifier.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
#     classifier.add(BatchNormalization(axis=-1))
    
    classifier.add(Conv2D(128, (3, 3), activation='relu', padding='same'))
#     classifier.add(BatchNormalization(axis=-1))
    classifier.add(MaxPooling2D(pool_size = (2, 2)))
    classifier.add(Dropout(0.25))
    
    classifier.add(Flatten())
#     classifier.add(Dense(1024, activation='relu'))
    classifier.add(BatchNormalization())
#     classifier.add(Dropout(0.5))
    classifier.add(Dense(units = 1, activation = 'sigmoid'))
    classifier.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['acc'])
    return classifier

neuralnetwork = cnn(img_size)
neuralnetwork.summary()

plot_model(neuralnetwork, to_file="face_mask_model.png", show_shapes=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 96, 96, 32)        320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 64)        18496
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 64)        256
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 16, 16, 64)        0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 16, 16, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 16, 16, 128)       73856
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 16, 16, 128)       147584
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 8, 8, 128)         0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 8, 8, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 8192)              0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 8192)              32768
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 8193
# =================================================================
# Total params: 318,401
# Trainable params: 301,889
# Non-trainable params: 16,512
# _________________________________________________________________

# %%
history = neuralnetwork.fit(
    x=X, y=y,
    validation_split = 0.05, batch_size=5,
    callbacks=[es, ckpt, rlp], epochs = 1000, 
    class_weight={0:1, 1:2.664}
)
# Out:
# Train on 5461 samples, validate on 288 samples
# Epoch 1/1000
# 5461/5461 [==============================] - 130s 24ms/step - loss: 1.1274 - acc: 0.6299 - val_loss: 1.8587 - val_acc: 0.6597
#
# Epoch 00001: loss improved from inf to 1.12736, saving model to face_mask_model.h5
# Epoch 2/1000
# 5461/5461 [==============================] - 115s 21ms/step - loss: 1.1278 - acc: 0.6567 - val_loss: 5.6917 - val_acc: 0.7049
#
# Epoch 00002: loss did not improve from 1.12736
# Epoch 3/1000
# 5461/5461 [==============================] - 114s 21ms/step - loss: 1.1934 - acc: 0.6442 - val_loss: 7.1688 - val_acc: 0.3264
#
# Epoch 00003: loss did not improve from 1.12736
# Epoch 4/1000
# 5461/5461 [==============================] - 115s 21ms/step - loss: 1.2312 - acc: 0.6404 - val_loss: 3.4793 - val_acc: 0.4097
#
# Epoch 00004: loss did not improve from 1.12736
# Epoch 5/1000
# 5461/5461 [==============================] - 115s 21ms/step - loss: 1.1488 - acc: 0.6325 - val_loss: 1.4989 - val_acc: 0.6319
#
# Epoch 00005: loss did not improve from 1.12736
# Epoch 6/1000
# 5461/5461 [==============================] - 121s 22ms/step - loss: 1.0859 - acc: 0.6376 - val_loss: 1.4073 - val_acc: 0.7326
#
# Epoch 00006: loss improved from 1.12736 to 1.08586, saving model to face_mask_model.h5
# Epoch 7/1000
# 5461/5461 [==============================] - 117s 21ms/step - loss: 1.0183 - acc: 0.6719 - val_loss: 1.4376 - val_acc: 0.7049
#
# Epoch 00007: loss improved from 1.08586 to 1.01826, saving model to face_mask_model.h5
# Epoch 8/1000
# 5461/5461 [==============================] - 115s 21ms/step - loss: 0.9793 - acc: 0.6737 - val_loss: 1.4233 - val_acc: 0.6667
#
# Epoch 00008: loss improved from 1.01826 to 0.97925, saving model to face_mask_model.h5
# Epoch 9/1000
# 5461/5461 [==============================] - 118s 22ms/step - loss: 0.9536 - acc: 0.6748 - val_loss: 1.5672 - val_acc: 0.7222
#
# Epoch 00009: loss improved from 0.97925 to 0.95364, saving model to face_mask_model.h5
# Epoch 10/1000
# 5461/5461 [==============================] - 116s 21ms/step - loss: 0.9210 - acc: 0.6869 - val_loss: 1.5365 - val_acc: 0.6806
#
# Epoch 00010: loss improved from 0.95364 to 0.92097, saving model to face_mask_model.h5
# Epoch 11/1000
# 5461/5461 [==============================] - 119s 22ms/step - loss: 0.8926 - acc: 0.6960 - val_loss: 1.8131 - val_acc: 0.6354
#
# Epoch 00011: loss improved from 0.92097 to 0.89264, saving model to face_mask_model.h5
# Epoch 12/1000
# 5461/5461 [==============================] - 116s 21ms/step - loss: 0.8845 - acc: 0.6927 - val_loss: 1.3485 - val_acc: 0.6806
#
# Epoch 00012: loss improved from 0.89264 to 0.88446, saving model to face_mask_model.h5
# Epoch 13/1000
# 5461/5461 [==============================] - 117s 21ms/step - loss: 0.8471 - acc: 0.7050 - val_loss: 1.8853 - val_acc: 0.5521
#
# Epoch 00013: loss improved from 0.88446 to 0.84711, saving model to face_mask_model.h5
# Epoch 14/1000
# 5461/5461 [==============================] - 117s 22ms/step - loss: 0.8290 - acc: 0.7110 - val_loss: 1.3480 - val_acc: 0.6979
#
# Epoch 00014: loss improved from 0.84711 to 0.82900, saving model to face_mask_model.h5
# Epoch 15/1000
# 5461/5461 [==============================] - 119s 22ms/step - loss: 0.8211 - acc: 0.7204 - val_loss: 1.4354 - val_acc: 0.7292
#
# Epoch 00015: loss improved from 0.82900 to 0.82115, saving model to face_mask_model.h5
# Epoch 16/1000
# 5461/5461 [==============================] - 120s 22ms/step - loss: 0.8165 - acc: 0.7226 - val_loss: 1.7379 - val_acc: 0.6771
#
# Epoch 00016: loss improved from 0.82115 to 0.81649, saving model to face_mask_model.h5
# Epoch 17/1000
# 5461/5461 [==============================] - 115s 21ms/step - loss: 0.8016 - acc: 0.7299 - val_loss: 1.3311 - val_acc: 0.7222
#
# Epoch 00017: loss improved from 0.81649 to 0.80164, saving model to face_mask_model.h5
# Epoch 18/1000
# 5461/5461 [==============================] - 115s 21ms/step - loss: 0.8078 - acc: 0.7222 - val_loss: 1.5315 - val_acc: 0.6597
#
# Epoch 00018: loss did not improve from 0.80164
# Epoch 19/1000
# 5461/5461 [==============================] - 166s 30ms/step - loss: 0.7787 - acc: 0.7374 - val_loss: 1.0727 - val_acc: 0.7708
#
# Epoch 00019: loss improved from 0.80164 to 0.77871, saving model to face_mask_model.h5
# Epoch 20/1000
# 5461/5461 [==============================] - 159s 29ms/step - loss: 0.7669 - acc: 0.7435 - val_loss: 1.0863 - val_acc: 0.8021
#
# Epoch 00020: loss improved from 0.77871 to 0.76691, saving model to face_mask_model.h5
# Epoch 21/1000
# 5461/5461 [==============================] - 152s 28ms/step - loss: 0.7568 - acc: 0.7455 - val_loss: 1.2624 - val_acc: 0.7188
#
# Epoch 00021: loss improved from 0.76691 to 0.75679, saving model to face_mask_model.h5
# Epoch 22/1000
# 5461/5461 [==============================] - 146s 27ms/step - loss: 0.7571 - acc: 0.7457 - val_loss: 1.3099 - val_acc: 0.7257
#
# Epoch 00022: loss did not improve from 0.75679
# Epoch 23/1000
# 5461/5461 [==============================] - 147s 27ms/step - loss: 0.7704 - acc: 0.7354 - val_loss: 1.1743 - val_acc: 0.7639
#
# Epoch 00023: loss did not improve from 0.75679
# Epoch 24/1000
# 5461/5461 [==============================] - 165s 30ms/step - loss: 0.7992 - acc: 0.7310 - val_loss: 1.0324 - val_acc: 0.8229
#
# Epoch 00024: loss did not improve from 0.75679
# Epoch 25/1000
# 5461/5461 [==============================] - 166s 30ms/step - loss: 0.7733 - acc: 0.7272 - val_loss: 1.1205 - val_acc: 0.8021
#
# Epoch 00025: loss did not improve from 0.75679
# Epoch 26/1000
# 5461/5461 [==============================] - 158s 29ms/step - loss: 0.7676 - acc: 0.7352 - val_loss: 1.0748 - val_acc: 0.7986
#
# Epoch 00026: loss did not improve from 0.75679
# Epoch 27/1000
# 5461/5461 [==============================] - 152s 28ms/step - loss: 0.7552 - acc: 0.7391 - val_loss: 1.0388 - val_acc: 0.7951
#
# Epoch 00027: loss improved from 0.75679 to 0.75519, saving model to face_mask_model.h5
# Epoch 28/1000
# 5461/5461 [==============================] - 123s 22ms/step - loss: 0.7321 - acc: 0.7579 - val_loss: 1.0360 - val_acc: 0.8021
#
# Epoch 00028: loss improved from 0.75519 to 0.73207, saving model to face_mask_model.h5
# Epoch 29/1000
# 5461/5461 [==============================] - 123s 22ms/step - loss: 0.7329 - acc: 0.7511 - val_loss: 1.1316 - val_acc: 0.7778
#
# Epoch 00029: loss did not improve from 0.73207
# Epoch 30/1000
# 5461/5461 [==============================] - 118s 22ms/step - loss: 0.7293 - acc: 0.7570 - val_loss: 1.1681 - val_acc: 0.7604
#
# Epoch 00030: loss improved from 0.73207 to 0.72929, saving model to face_mask_model.h5
# Epoch 31/1000
# 5461/5461 [==============================] - 112s 21ms/step - loss: 0.7380 - acc: 0.7537 - val_loss: 1.1636 - val_acc: 0.7674
#
# Epoch 00031: loss did not improve from 0.72929
# Epoch 32/1000
# 5461/5461 [==============================] - 112s 20ms/step - loss: 0.7134 - acc: 0.7596 - val_loss: 1.1591 - val_acc: 0.7743
#
# Epoch 00032: loss improved from 0.72929 to 0.71335, saving model to face_mask_model.h5
# Epoch 33/1000
# 5461/5461 [==============================] - 118s 22ms/step - loss: 0.7186 - acc: 0.7608 - val_loss: 1.0244 - val_acc: 0.8021
#
# Epoch 00033: loss did not improve from 0.71335
# Epoch 34/1000
# 5461/5461 [==============================] - 116s 21ms/step - loss: 0.7074 - acc: 0.7696 - val_loss: 1.0271 - val_acc: 0.7917
#
# Epoch 00034: loss improved from 0.71335 to 0.70741, saving model to face_mask_model.h5
# Epoch 35/1000
# 5461/5461 [==============================] - 116s 21ms/step - loss: 0.6959 - acc: 0.7726 - val_loss: 1.0906 - val_acc: 0.7882
#
# Epoch 00035: loss improved from 0.70741 to 0.69587, saving model to face_mask_model.h5
# Epoch 36/1000
# 5461/5461 [==============================] - 115s 21ms/step - loss: 0.6829 - acc: 0.7773 - val_loss: 1.0173 - val_acc: 0.8160
#
# Epoch 00036: loss improved from 0.69587 to 0.68293, saving model to face_mask_model.h5
# Epoch 37/1000
# 5461/5461 [==============================] - 111s 20ms/step - loss: 0.6797 - acc: 0.7689 - val_loss: 1.0571 - val_acc: 0.7812
#
# Epoch 00037: loss improved from 0.68293 to 0.67971, saving model to face_mask_model.h5
# Epoch 38/1000
# 5461/5461 [==============================] - 113s 21ms/step - loss: 0.7024 - acc: 0.7671 - val_loss: 1.0536 - val_acc: 0.7812
#
# Epoch 00038: loss did not improve from 0.67971
# Epoch 39/1000
# 5461/5461 [==============================] - 114s 21ms/step - loss: 0.6955 - acc: 0.7704 - val_loss: 1.0527 - val_acc: 0.7882
#
# Epoch 00039: loss did not improve from 0.67971
# Epoch 40/1000
# 5461/5461 [==============================] - 110s 20ms/step - loss: 0.6929 - acc: 0.7751 - val_loss: 1.0129 - val_acc: 0.8194
#
# Epoch 00040: loss did not improve from 0.67971
# Epoch 41/1000
# 5461/5461 [==============================] - 111s 20ms/step - loss: 0.6839 - acc: 0.7728 - val_loss: 1.0092 - val_acc: 0.7951
#
# Epoch 00041: loss did not improve from 0.67971
# Epoch 42/1000
# 5461/5461 [==============================] - 111s 20ms/step - loss: 0.6830 - acc: 0.7709 - val_loss: 1.0309 - val_acc: 0.8056
#
# Epoch 00042: loss did not improve from 0.67971
# Epoch 43/1000
# 5461/5461 [==============================] - 113s 21ms/step - loss: 0.6860 - acc: 0.7729 - val_loss: 1.1906 - val_acc: 0.7847
#
# Epoch 00043: loss did not improve from 0.67971
# Epoch 44/1000
# 5461/5461 [==============================] - 113s 21ms/step - loss: 0.6812 - acc: 0.7739 - val_loss: 0.9876 - val_acc: 0.8056
#
# Epoch 00044: loss did not improve from 0.67971
# Epoch 45/1000
# 5461/5461 [==============================] - 112s 20ms/step - loss: 0.6704 - acc: 0.7781 - val_loss: 1.0871 - val_acc: 0.8056
#
# Epoch 00045: loss improved from 0.67971 to 0.67035, saving model to face_mask_model.h5
# Epoch 46/1000
# 5461/5461 [==============================] - 113s 21ms/step - loss: 0.6789 - acc: 0.7753 - val_loss: 1.1292 - val_acc: 0.7882
#
# Epoch 00046: loss did not improve from 0.67035
# Epoch 47/1000
# 5461/5461 [==============================] - 114s 21ms/step - loss: 0.6825 - acc: 0.7707 - val_loss: 1.0948 - val_acc: 0.8056
#
# Epoch 00047: loss did not improve from 0.67035
# Epoch 48/1000
# 5461/5461 [==============================] - 114s 21ms/step - loss: 0.6859 - acc: 0.7735 - val_loss: 1.0097 - val_acc: 0.8056
#
# Epoch 00048: loss did not improve from 0.67035
# Epoch 49/1000
# 5461/5461 [==============================] - 116s 21ms/step - loss: 0.6769 - acc: 0.7764 - val_loss: 1.1464 - val_acc: 0.7847
#
# Epoch 00049: loss did not improve from 0.67035
# Epoch 50/1000
# 5461/5461 [==============================] - 113s 21ms/step - loss: 0.6796 - acc: 0.7702 - val_loss: 1.1601 - val_acc: 0.7847
#
# Epoch 00050: loss did not improve from 0.67035
# Epoch 51/1000
# 5461/5461 [==============================] - 113s 21ms/step - loss: 0.6778 - acc: 0.7742 - val_loss: 0.9828 - val_acc: 0.8125
#
# Epoch 00051: loss did not improve from 0.67035
# Epoch 52/1000
# 5461/5461 [==============================] - 113s 21ms/step - loss: 0.6851 - acc: 0.7797 - val_loss: 1.0283 - val_acc: 0.8194
#
# Epoch 00052: loss did not improve from 0.67035
# Epoch 53/1000
# 5461/5461 [==============================] - 110s 20ms/step - loss: 0.6855 - acc: 0.7720 - val_loss: 1.0484 - val_acc: 0.8056
#
# Epoch 00053: loss did not improve from 0.67035
# Epoch 54/1000
# 5461/5461 [==============================] - 119s 22ms/step - loss: 0.6860 - acc: 0.7737 - val_loss: 1.0939 - val_acc: 0.7917
#
# Epoch 00054: loss did not improve from 0.67035
# Epoch 55/1000
# 5461/5461 [==============================] - 114s 21ms/step - loss: 0.6889 - acc: 0.7742 - val_loss: 1.0833 - val_acc: 0.7882
#
# Epoch 00055: loss did not improve from 0.67035
# Epoch 56/1000
# 5461/5461 [==============================] - 119s 22ms/step - loss: 0.6808 - acc: 0.7704 - val_loss: 0.9854 - val_acc: 0.8021
#
# Epoch 00056: loss did not improve from 0.67035
# Epoch 57/1000
# 5461/5461 [==============================] - 123s 22ms/step - loss: 0.6844 - acc: 0.7777 - val_loss: 1.0488 - val_acc: 0.8090
#
# Epoch 00057: loss did not improve from 0.67035
# Epoch 58/1000
# 5461/5461 [==============================] - 124s 23ms/step - loss: 0.6913 - acc: 0.7775 - val_loss: 1.0855 - val_acc: 0.8021
#
# Epoch 00058: loss did not improve from 0.67035
# Epoch 59/1000
# 5461/5461 [==============================] - 127s 23ms/step - loss: 0.6783 - acc: 0.7753 - val_loss: 1.0152 - val_acc: 0.8125
#
# Epoch 00059: loss did not improve from 0.67035
# Epoch 60/1000
# 5461/5461 [==============================] - 125s 23ms/step - loss: 0.6785 - acc: 0.7713 - val_loss: 1.1189 - val_acc: 0.8021
#
# Epoch 00060: loss did not improve from 0.67035
# Epoch 61/1000
# 5461/5461 [==============================] - 127s 23ms/step - loss: 0.6780 - acc: 0.7737 - val_loss: 1.0942 - val_acc: 0.8125
#
# Epoch 00061: loss did not improve from 0.67035
# Epoch 00061: early stopping

# %%
fig, ax = plt.subplots(2, 1, figsize=(20, 12))

fig.suptitle('Model Performance', fontsize=24) 

ax[0].plot(history.history['loss'], label='t-loss')
ax[0].plot(history.history['val_loss'], label='v-loss')
ax[0].set_title('Loss', fontsize=18)
ax[0].set_ylabel('Loss')

ax[1].plot(history.history['acc'], label='t-acc')
ax[1].plot(history.history['val_acc'], label='v-acc')
ax[1].set_title('Score', fontsize=18)
ax[1].set_ylabel('Score')


for i in range(2):
    ax[i].grid()
    ax[i].legend()
    ax[i].set_xlabel('Epochs')
